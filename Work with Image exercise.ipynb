# %%
from PIL import Image

# %%
word=Image.open('word_matrix.png')

# %%
word
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x2BC1E5DA908>

# %%
mask=Image.open('mask.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x2BC1E0E9208>

# %%
mask.size
# Out:
# (505, 251)

# %%
word.size
# Out:
# (1015, 559)

# %%
mask=mask.resize((1015,559))

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x2BC1E644E08>

# %%
mask.putalpha(150)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x2BC1E644E08>

# %%
word.paste(mask,(0,0),mask)

# %%
word
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x2BC1E5DA908>
